# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiorolnic/anonim/blob/main/notebook/colab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os.path
import numpy as np
import pandas as pd

# %%
# !pip install transformers
# !pip install datasets
# !pip install seqeval
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.11.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.47)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (1.18.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.5)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.63.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval) (1.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.1.0)

# %%
df1 = pd.read_json("https://github.com/sergiorolnic/anonim/blob/tirocinio/data/esempio.json?raw=true")
cn = pd.read_csv('https://raw.githubusercontent.com/nicolomantini/lista_cognomi_italiani/master/cognomi.txt', header=None)
cn.columns = ["cognome"]
femal_name = pd.read_json('https://github.com/sergiorolnic/anonim/blob/tirocinio/data/ITGivenFemale.json?raw=true')
male_name = pd.read_json('https://github.com/sergiorolnic/anonim/blob/tirocinio/data/ITGivenMale.json?raw=true')
mixt = pd.concat([male_name,femal_name])
index = pd.Index(range(1, 9087, 1))
mixt.set_index(index)

def fill_missing(column_val):
    if column_val == "": 
        column_val = mixt["name"].iloc[np.random.randint(9086)]
    else:
         column_val = column_val
    return column_val

cn["nome"] = ""
cn['nome'] = cn['nome'].apply(fill_missing) 
cn["nome"] = cn["nome"].str.upper()
cn["cognome"] = cn["cognome"].str.upper()
dataframe = pd.DataFrame(df1)
dataframe["cognome"] = cn["cognome"][0:15000]
dataframe["nome"] = cn["nome"][0:15000]
dataframe2 = pd.DataFrame(df1[0:6740])
dataframe2["cognome"] = list(cn["cognome"][15000:21740])
dataframe2["nome"] = list(cn["nome"][15000:21740])

dataframe =dataframe.append(df1, ignore_index = True)
dataframe =dataframe.append(dataframe2, ignore_index = True)
dataframe = dataframe.sample(frac=1).reset_index(drop=True)
test_data_df =dataframe[35000:36000]
dataframe = dataframe[0:35000]

# %%
dataframe["full_name"] = dataframe["cognome"] + " " +dataframe["nome"]

# %%
dataframe
# Out:
#        cod_prv  cod_com     id sesso  data_nascita  \
# 0            5       22  31048     M      30051977
# 1            5       22  13454     M       7121941
# 2            5       22  20777     M       6071932
# 3            5       22  26207     F       5061979
# 4            5       22  15122     F       7031944
# ...        ...      ...    ...   ...           ...
# 34995        5       22  25331     F      22011931
# 34996        5       22  17839     F      25091945
# 34997        5       22   4907     F      22091943
# 34998        5       22  28361     F       4091925
# 34999        5       22  20132     M      19101952
#
#                     luogo_nascita                cf prov_nascita  comune_res  \
# 0                      MONCALIERI  LRSGRL77E30F335T           TO  MONCALIERI
# 1                          TORINO  CVLMLE41T07L219Z           TO  MONCALIERI
# 2                          RICADI  DCSPQL32L06H271W           VV  MONCALIERI
# 3                      MONCALIERI  GRGCST79H45F335M           TO  MONCALIERI
# 4                          TORINO  CRLLVN44C47L219H           TO  MONCALIERI
# ...                           ...               ...          ...         ...
# 34995                      TORINO  GLTGNN31A62L219H           TO  MONCALIERI
# 34996              RUVO DEL MONTE  DRACRN45P65H646V           PZ  MONCALIERI
# 34997                      CALUSO  BLLSLV43P62B435G           AO  MONCALIERI
# 34998                  MONCALIERI  GVRMRA25P44F335O           TO  MONCALIERI
# 34999  CASTRONUOVO DI SANT'ANDREA  DCNDNC52R19C345V           PZ  MONCALIERI
#
#       prov_res  ...                       indirizzo    cap     dato1   dato2  \
# 0           TO  ...                STRADA PASUBIO 7  10024  24032017  119393
# 1           TO  ...           STRADA REVIGLIASCO 72  10024  24032017   14649
# 2           TO  ...               STRADA CENASCO 87  10024  24032017   99924
# 3           TO  ...  STRADA VECCHIA DEL MORIONDO 30  10024  24032017  122651
# 4           TO  ...              PIAZZA UMBERTO I 1  10024  24032017   18645
# ...        ...  ...                             ...    ...       ...     ...
# 34995       TO  ...                   CORSO ROMA 85  10024  24032017   49167
# 34996       TO  ...               STRADA GENOVA 136  10024  24032017   16913
# 34997       TO  ...           VIA TORQUATO TASSO 14  10024  24032017   21784
# 34998       TO  ...            VIA NAZARIO SAURO 17  10024  24032017   48062
# 34999       TO  ...             STRADA CARIGNANO 62  10024  24032017   89695
#
#        dato3     dato4     dato5              dato6     dato7  \
# 0          2  22122012  22012007  12112021 05:49:25  CENS2011
# 1          1  26011968  26011968  12112021 05:49:25  CENS2011
# 2          1   4061980   6061978  12112021 05:49:25  CENS2011
# 3          2  22122008  22122008  12112021 05:49:25  CENS2011
# 4          1   9051983   9051983  12112021 05:49:25  CENS2011
# ...      ...       ...       ...                ...       ...
# 34995      1  10032008  20051954  12112021 05:49:25  CENS2011
# 34996      2  29081980  29081980  12112021 05:49:25  CENS2011
# 34997      1   7091984   7091984  12112021 05:49:25  CENS2011
# 34998      1  14031997   4091925  12112021 05:49:25  CENS2011
# 34999      1  15111978  15111978  12112021 05:49:25  CENS2011
#
#                   full_name
# 0             LANZOTTO NEVE
# 1            TEDESCHI TISBE
# 2           DERONZO ENERINA
# 3              GARCIA GRATO
# 4         TRIGOSO CARISSIMO
# ...                     ...
# 34995       FRUZZETTI ESTER
# 34996      ZAMPOLI TERZILLA
# 34997  RADIGHIERI PALESTINO
# 34998      GORLA LIUTPRANDO
# 34999       DEL DEO FERNERO
#
# [35000 rows x 21 columns]

# %%
test_dataframe = dataframe[34000:35000]
true_indirizzi = list(test_dataframe["indirizzo"])
true_nomi = list(test_dataframe["nome"])
true_cognomi = list(test_dataframe["cognome"])
dataframe.drop(columns=["cognome", "nome"], inplace=True)
test_dataframe.drop(columns=["full_name"], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
test_dataframe
# Out:
#        cod_prv  cod_com     id     cognome        nome sesso  data_nascita  \
# 34000        5       22  13738     TESTAI'      FELTRE     F      30051968
# 34001        5       22  17127       VIOLI       CESCO     M      16021943
# 34002        5       22  16012    VALENZIA      PERSIA     F       2121936
# 34003        5       22  30198  INTERRANTE    IFIGENIA     F       2091929
# 34004        5       22  10428       SERRI  ROSSELLINA     M       8031980
# ...        ...      ...    ...         ...         ...   ...           ...
# 34995        5       22  13861       TILLI     ELLIANA     F       7021937
# 34996        5       22    191   PAPURELLO    SILVERIA     M       4011935
# 34997        5       22  18703  ZUCCARELLO   ANDRIETTO     M      28011981
# 34998        5       22  18224     ZAVAGLI     GIOVINA     M      30061946
# 34999        5       22  13415      TAVIAN      SELENE     F      20021970
#
#              luogo_nascita                cf prov_nascita  ... citt  \
# 34000               TORINO  CDRSFN68E70L219I           TO  ...  ITA
# 34001                 ASTI  CRVNNI43B16A479I           AT  ...  ITA
# 34002       MONTALDO ROERO  CRGNTA36T42F408D           CN  ...  ITA
# 34003  OSPEDALETTO EUGANEO  GSLLVI29P42G167R           PD  ...  ITA
# 34004               TORINO  CLMSFN80C08L219D           TO  ...  ITA
# ...                    ...               ...          ...  ...  ...
# 34995          PRAMAGGIORE  CLNPLN37B47G981I           VE  ...  ITA
# 34996             SIRACUSA  CCLPQL35A04I754A           SR  ...  ITA
# 34997               TORINO  DGCFNC81A28L219V           TO  ...  ITA
# 34998               TORINO  DMNMCH46H30L219H           TO  ...  ITA
# 34999               TORINO  CVLLSU70B60L219F           TO  ...  ITA
#
#                         indirizzo    cap     dato1   dato2  dato3     dato4  \
# 34000        VIA ADA NEGRI 21/BIS  10024  24032017  123233      1  22042009
# 34001            STRADA TORINO 67  10024  24032017   15831      1  27021969
# 34002     VIA ALFONSO LAMARMORA 9  10024  24032017   46718      1   3121963
# 34003                 VIA FIUME 6  10024  24032017   48384      1  14121999
# 34004  VIA AMILCARE PONCHIELLI 38  10024  24032017  126406      3  12092011
# ...                           ...    ...       ...     ...    ...       ...
# 34995              VIA PALESTRO 6  10024  24032017   11070      2   9111960
# 34996            VIA SESTRIERE 53  10024  24032017   10065      1   3021966
# 34997  VIA AMILCARE PONCHIELLI 62  10024  24032017   16325      3  28011981
# 34998            CORSO TRIESTE 59  10024  24032017   16116      1  19121968
# 34999        VIA DELLA GINESTRA 2  10024  24032017  101460      1  25021993
#
#           dato5              dato6     dato7
# 34000  22042009  12112021 05:49:25  CENS2011
# 34001  27021969  12112021 05:49:25  CENS2011
# 34002   3121963  12112021 05:49:25  CENS2011
# 34003  11081955  12112021 05:49:25  CENS2011
# 34004  12092011  12112021 05:49:25  CENS2011
# ...         ...                ...       ...
# 34995   7031960  12112021 05:49:25  CENS2011
# 34996   3021966  12112021 05:49:25  CENS2011
# 34997   6061969  12112021 05:49:25  CENS2011
# 34998  19121968  12112021 05:49:25  CENS2011
# 34999  25021993  12112021 05:49:25  CENS2011
#
# [1000 rows x 22 columns]

# %%
cols1 = dataframe.columns.tolist()

# %%
import random

# %%
random.shuffle(cols1)

# %%
first_shuffle_data = dataframe[cols1][0:10000]

# %%
random.shuffle(cols1)

second_shuffle_data = dataframe[cols1][10000:20000]

# %%
def create_token_and_labels(dataset, token_array, tag_array):
  data = dataset

 
  for index, row in data.iterrows():
    tokens = []
    tags = []

    for x, value in row.iteritems():
    
  
      if x == "indirizzo":
        y = value.split()
        first= True;
        for word in y:
          tokens.append(str(word))
          if first:
            tags.append("B-Ind")
            first = False
          else:
            tags.append("I-Ind") 
      elif x == "full_name":
        y = value.split()
        first= True;
        for word in y:
          tokens.append(str(word))
          if first:
            tags.append("B-Per")
            first = False
          else:
            if row["sesso"] == "M":
              tags.append("I-Per-M")
            else:
              tags.append("I-Per-F")


               

      else:
        tokens.append(str(value))
        tags.append("O") 
  
    token_array.append(tokens)
    tag_array.append(tags)

# %%
token_docs = []
tag_docs = []
#create_token_and_labels(dataframe,token_docs,tag_docs)
create_token_and_labels(first_shuffle_data,token_docs,tag_docs)
create_token_and_labels(second_shuffle_data,token_docs,tag_docs)

# %%
test_tag= []
test_token = []
create_token_and_labels(test_dataframe,test_token,test_tag)

# %%
test_tag
# Out:
# [['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
# ...
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'B-Ind',
#   'I-Ind',
#   'I-Ind',
#   'I-Ind',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O']]

# %%
len(test_tag)
# Out:
# 1000

# %%
len(token_docs)
# Out:
# 20000

# %%
texts, tags = token_docs, tag_docs
from sklearn.model_selection import train_test_split
train_texts, val_texts, train_tags, val_tags = train_test_split(texts, tags, test_size=.2)

# %%
unique_tags = set(tag for doc in tags for tag in doc)
tag2id = {tag: id for id, tag in enumerate(unique_tags)}
id2tag = {id: tag for tag, id in tag2id.items()}
id2tag
# Out:
# {0: 'I-Per-F', 1: 'B-Per', 2: 'I-Per-M', 3: 'O', 4: 'I-Ind', 5: 'B-Ind'}

# %%
from transformers import BertTokenizerFast

#tokenizer = BertTokenizerFast.from_pretrained('bert-base-uncased')
tokenizer = BertTokenizerFast.from_pretrained('dbmdz/bert-base-italian-cased',num_labels=len(unique_tags))

# %%
train_encodings = tokenizer(train_texts, is_split_into_words=True, padding="max_length",return_offsets_mapping=True)

# %%
val_encodings = tokenizer(val_texts, is_split_into_words=True,padding="max_length", return_offsets_mapping=True)

# %%
test_encodings = tokenizer(test_token, is_split_into_words=True,padding="max_length", return_offsets_mapping=True)

# %%
def encode_tags(tags, encodings):
    labels = [[tag2id[tag] for tag in doc] for doc in tags]
    encoded_labels = []
    for doc_labels, doc_offset in zip(labels, encodings.offset_mapping):
        # create an empty array of -100
        doc_enc_labels = np.ones(len(doc_offset),dtype=int) * -100
        arr_offset = np.array(doc_offset)

        # set labels whose first offset position is 0 and the second is not 0
        mask = (arr_offset[:, 0] == 0) & (arr_offset[:, 1] != 0)
        doc_enc_labels[mask] = doc_labels[:np.sum(mask)]
        encoded_labels.append(doc_enc_labels.tolist())
        
      #  doc_enc_labels[(arr_offset[:,0] == 0) & (arr_offset[:,1] != 0)] = doc_labels
       # encoded_labels.append(doc_enc_labels.tolist())

    return encoded_labels
train_labels = encode_tags(train_tags, train_encodings)
val_labels = encode_tags(val_tags, val_encodings)

# %%
test_labels = encode_tags(test_tag, test_encodings)

# %%
import tensorflow as tf

# %%
train_encodings.pop("offset_mapping") # we don't want to pass this to the model
val_encodings.pop("offset_mapping")

train_dataset = tf.data.Dataset.from_tensor_slices((
    dict(train_encodings),
    train_labels
))

# %%
val_dataset = tf.data.Dataset.from_tensor_slices((
    dict(val_encodings),
    val_labels
))

# %%
test_encodings.pop("offset_mapping")
test_dataset = tf.data.Dataset.from_tensor_slices((
    dict(test_encodings),
    test_labels
))

# %%
from transformers import TFBertForTokenClassification

# %%
model = TFBertForTokenClassification.from_pretrained('dbmdz/bert-base-italian-cased',num_labels=len(unique_tags))
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss=model.compute_loss,metrics=metric) # can also use any keras loss fn
model.summary()
# Out:
# Downloading:   0%|          | 0.00/515M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFBertForTokenClassification.
#
# Some layers of TFBertForTokenClassification were not initialized from the model checkpoint at dbmdz/bert-base-italian-cased and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model: "tf_bert_for_token_classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bert (TFBertMainLayer)      multiple                  109337088
#
#  dropout_37 (Dropout)        multiple                  0
#
#  classifier (Dense)          multiple                  4614
#
# =================================================================
# Total params: 109,341,702
# Trainable params: 109,341,702
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_dataset.shuffle(1000).batch(8), epochs=1,validation_data=val_dataset, batch_size=8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-04c4cefc97ba> in <module>()
# ----> 1 model.fit(train_dataset.shuffle(1000).batch(8), epochs=1,validation_data=val_dataset, batch_size=8)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in autograph_handler(*args, **kwargs)
#    1145           except Exception as e:  # pylint:disable=broad-except
#    1146             if hasattr(e, "ag_error_metadata"):
# -> 1147               raise e.ag_error_metadata.to_exception(e)
#    1148             else:
#    1149               raise
#
# AttributeError: in user code:
#
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.7/dist-packages/transformers/modeling_tf_utils.py", line 875, in compute_loss  *
#         return super().compute_loss(*args, **kwargs)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/training.py", line 919, in compute_loss  **
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/compile_utils.py", line 199, in __call__
#         y_t, y_p, sw = match_dtype_and_rank(y_t, y_p, sw)
#     File "/usr/local/lib/python3.7/dist-packages/keras/engine/compile_utils.py", line 684, in match_dtype_and_rank
#         if ((y_t.dtype.is_floating and y_p.dtype.is_floating) or
#
#     AttributeError: 'NoneType' object has no attribute 'dtype'

# %%
model = TFBertForTokenClassification.from_pretrained("load_model")
# Out:
# All model checkpoint layers were used when initializing TFBertForTokenClassification.
#
# All the layers of TFBertForTokenClassification were initialized from the model checkpoint at load_model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForTokenClassification for predictions without further training.

# %%
import time

# %%
start= time.time()
x = test_dataset.shuffle(3)
result = model.predict(x.batch(8))
stop= time.time()
print((stop-start)/10)
# Out:
# 26.203273582458497

# %%
prediction = np.argmax(result, axis=-1)
#prediction = [id2tag[i] for i in prediction]

# eu -> B-ORG, german -> B-MISC, british -> B-MISC
print(prediction)
# Out:
# 0

# %%
prediction
# Out:
# 0

# %%
from transformers import pipeline

nlp = pipeline('ner', model=model, tokenizer=tokenizer,aggregation_strategy="first")

# %%
nlp("5 10 SERGIU ROLNIC M 8031935 BIANZE BTAZEI35C08A847I VC MONCALIERI TO ITA STRADA GENOVA 58 10024 24032017 10003 13101963 3101963 12112021 05:49:25 CENS2011")
# Out:
# [{'end': 4,
#   'entity_group': 'LABEL_0',
#   'score': 0.9999425,
#   'start': 0,
#   'word': '5 10'},
#  {'end': 11,
#   'entity_group': 'LABEL_3',
#   'score': 0.99803275,
#   'start': 5,
#   'word': 'SERGIU'},
#  {'end': 18,
#   'entity_group': 'LABEL_2',
#   'score': 0.96980053,
#   'start': 12,
#   'word': 'ROLNIC'},
#  {'end': 73,
#   'entity_group': 'LABEL_0',
#   'score': 0.9999405,
#   'start': 19,
#   'word': 'M 8031935 BIANZE BTAZEI35C08A847I VC MONCALIERI TO ITA'},
#  {'end': 80,
#   'entity_group': 'LABEL_1',
#   'score': 0.99974257,
#   'start': 74,
#   'word': 'STRADA'},
#  {'end': 90,
#   'entity_group': 'LABEL_4',
#   'score': 0.99895275,
#   'start': 81,
#   'word': 'GENOVA 58'},
#  {'end': 155,
#   'entity_group': 'LABEL_0',
#   'score': 0.9999304,
#   'start': 91,
#   'word': '10024 24032017 10003 13101963 3101963 12112021 05 : 49 : 25 CENS2011'}]

# %%
print(id2tag)
# Out:
# {0: 'O', 1: 'B-Per', 2: 'I-Ind', 3: 'I-Per-F', 4: 'B-Ind', 5: 'I-Per-M'}

# %%
test_dataframe
# Out:
# Empty DataFrame
# Columns: [cod_prv, cod_com, id, cognome, nome, sesso, data_nascita, luogo_nascita, cf, prov_nascita, comune_res, prov_res, citt, indirizzo, cap, dato1, dato2, dato3, dato4, dato5, dato6, dato7]
# Index: []

# %%
import time

# %%
list_durata = []
test_data = []
pred_nomi=[]
pred_cognomi = []
pred_indirizzi= []
data = test_dataframe
for index, row in data.iterrows():
  start = time.time()
  sentence = ""
 
  for x, value in row.iteritems():

    sentence += str(value) + " "

  test_data.append(sentence)
  ris = nlp(sentence)
  indirizzo = ""
  cognome = ""
  nome = ""
  for t in ris:
      
      if t["entity_group"] == "LABEL_1":
        indirizzo = t["word"]
      if t["entity_group"] == "LABEL_4":
        indirizzo += " " + t["word"]
        
      if t["entity_group"] == "LABEL_3":
        cognome =t["word"]
      
      if t["entity_group"] == "LABEL_2":
        nome = t["word"]
      
 
  pred_indirizzi.append(indirizzo)
  pred_cognomi.append(cognome)  
  pred_nomi.append(nome)
  stop = time.time()
  list_durata.append(stop-start)

# %%
list_def = []
for x in list_durata:

  list_def.append((x-(sum(list_durata)/1000))**2)
    
varianza = sum(list_def)/1000

dizi = {"righe":1000,  "media": sum(list_durata)/1000, "varianza":varianza}
print(dizi)
# Out:
# {'righe': 1000, 'media': 0.6878732771873474, 'varianza': 0.028154227113346312}

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(true_nomi, pred_nomi))
# Out:
# 0.909

# %%
print(accuracy_score(true_cognomi, pred_cognomi))
# Out:
# 0.912

# %%
print(accuracy_score(true_indirizzi, pred_indirizzi))
# Out:
# 0.661

# %%
print(true_indirizzi)
print(pred_indirizzi)
# Out:
# ['STRADA GENOVA 208 BIS', 'VIA ANTONIO FOGAZZARO 4', 'CORSO ROMA 6', 'VIA GRAZIA DELEDDA 6', 'VIA MONTE BIANCO 28', 'VIA MONTEBELLO 1', 'VIA CAVOUR 22 TER', 'VIA VINCENZO BELLINI 23', 'STRADA DEL BOSSOLO 9 BIS', 'VIA ADA NEGRI 23', 'VIA MONVISO 21', 'CORSO ROMA 77', 'STRADA RIGOLFO 22 BIS', 'STRADA STUPINIGI 1 5', 'VIA CAVOUR 24', 'STRADA VILLA STELLA 9', 'VIA SESTRIERE 53 3', 'VIA PASTRENGO 33', "PIAZZA CADUTI PER LA LIBERTA' 3", 'STRADA LORETO 19', 'BORGATA TETTI PIATTI 41', 'VIA GIACOMO BOSSO 14', 'VIA BENVENUTO CELLINI 3', 'VIA CAVOUR 23', 'VIALE DELLE BETULLE 5', 'STRADA MAIOLE 21', 'VIA GIOTTO 8', 'VIA GIUSEPPE ROBALDO 1', 'STRADA GENOVA 107 3', 'VIA S.MARIA 24 E', 'STRADA GENOVA 147 TER', 'VIA MONVISO 19', 'VIA PIERO GOBETTI 3', 'VIA DEI MILLE 17', 'STRADA GENOVA 129 BIS', 'VIA GALILEO GALILEI 26', 'VIA CAVOUR 36', 'VIA GIOVANNI SEGANTINI 30 2', 'CORSO SAVONA 19', 'STRADA CASTELVECCHIO 6', 'VIA PESCHIERA 11', 'VIA AMILCARE PONCHIELLI 39', 'VIA S.CROCE 46', 'VIA SOMALIA 39', 'VIA BRUNO BUOZZI 11', 'STRADA S.ANSELMO 17', 'VIA CARLO COLLODI 4', 'STRADA GENOVA 222', 'VIA S.MARIA 29 1', 'VIA MONTE NERO 10', 'VIA CERNAIA 1', 'VIA PIERO GOBETTI 9', 'CORSO FRATELLI ROSSELLI 6', 'STRADA CARIGNANO 18', 'VIA GIOVANNI SEGANTINI 58', 'VIA GIOACCHINO ROSSINI 11', 'VIA CESARE PAVESE 17', 'STRADA PRACIOSA 6', 'STRADA TORINO 33', 'STRADA PRACIOSA 20 BIS', 'STRADA ROCCACATENE 7', 'CORSO TRIESTE 41 2', 'VIA SESTRIERE 27', 'PIAZZA BENGASI 26', 'STRADA CARIGNANO 56', 'VIA FIUME 24', 'CORSO ROMA 45', 'VIA MONVISO 12', 'CORSO TRIESTE 25 A', 'VIA LUIGI PIRANDELLO 2', 'VIA S.CROCE 27', 'BORGATA TETTI PIATTI 21', 'STRADA SANDA 63', 'BORGATA TETTI ROLLE 45 1', 'VIA SESTRIERE 49 TER', 'VIA FILIPPO TURATI 2', 'VIA S.MARTINO 35', 'CORSO ROMA 23', 'VIA PLAUTO 8', 'STRADA PASUBIO 38', 'VIA MARIO PANNUNZIO 5', 'VIA DEI MILLE 9', 'VIA S.GIOVANNI BOSCO 6', 'STRADA REVIGLIASCO 15 BIS', 'CORSO SAVONA 4', 'STRADA C. FERRERO DI CAMBIANO 51', 'VIA VILLAFRANCA 3', 'CORSO TRIESTE 73', 'VIALE ENRICO BERLINGUER 10 1', 'STRADA GIORGIO DEVALLE 21', 'VIA TIEPOLO 12', 'VIA S.GIOVANNI BOSCO 18', 'VIA SESTRIERE 13', 'VIA PASTRENGO 130', 'VIA JUGLARIS 62', 'STRADA CENASCO 7', 'VIA QUINTINO SELLA 34', 'STRADA VINOVO 12', 'STRADA VIVERO 10', 'VIA PIAVE 8']
# ['STRADA GENOVA 208', 'VIA ANTONIO FOGAZZARO 4', 'CORSO ROMA 6', 'VIA GRAZIA DELEDDA 6', 'VIA MONTE BIANCO 28', 'VIA MONTEBELLO 1', 'VIA CAVOUR 22', 'VIA VINCENZO BELLINI 23', 'STRADA DEL BOSSOLO 9', 'VIA ADA NEGRI 23', 'VIA MONVISO 21', 'CORSO ROMA 77', 'STRADA RIGOLFO 22', 'STRADA STUPINIGI 1', 'VIA CAVOUR 24', 'STRADA VILLA STELLA 9', 'VIA SESTRIERE 53', 'VIA PASTRENGO 33', "PIAZZA CADUTI PER LA LIBERTA'3", 'STRADA LORETO 19', 'BORGATA TETTI PIATTI 41', 'VIA GIACOMO BOSSO 14', 'VIA BENVENUTO CELLINI 3', 'VIA CAVOUR 23', 'VIALE DELLE BETULLE 5', 'STRADA MAIOLE 21', 'VIA GIOTTO 8', 'VIA GIUSEPPE ROBALDO 1', 'STRADA GENOVA 107', 'VIA S. MARIA 24', 'STRADA GENOVA 147', 'VIA MONVISO 19', 'VIA PIERO GOBETTI 3', 'VIA DEI MILLE 17', 'STRADA GENOVA 129', 'VIA GALILEO GALILEI 26', 'VIA CAVOUR 36', 'VIA GIOVANNI SEGANTINI 30', 'CORSO SAVONA 19', 'STRADA CASTELVECCHIO 6', 'VIA PESCHIERA 11', 'VIA AMILCARE PONCHIELLI 39', 'VIA S. CROCE 46', 'VIA SOMALIA 39', 'VIA BRUNO BUOZZI 11', 'STRADA S. ANSELMO 17', 'VIA CARLO COLLODI 4', 'STRADA GENOVA 222', 'VIA S. MARIA 29', 'VIA MONTE NERO 10', 'VIA CERNAIA 1', 'VIA PIERO GOBETTI 9', 'CORSO FRATELLI ROSSELLI 6', 'STRADA CARIGNANO 18', 'VIA GIOVANNI SEGANTINI 58', 'VIA GIOACCHINO ROSSINI 11', 'VIA CESARE PAVESE 17', 'STRADA PRACIOSA 6', 'STRADA TORINO 33', 'STRADA PRACIOSA 20', 'STRADA ROCCACATENE 7', 'CORSO TRIESTE 41', 'VIA SESTRIERE 27', 'PIAZZA BENGASI 26', 'STRADA CARIGNANO 56', 'VIA FIUME 24', 'CORSO ROMA 45', 'VIA MONVISO 12', 'CORSO TRIESTE 25', 'VIA LUIGI PIRANDELLO 2', 'VIA S. CROCE 27', 'BORGATA TETTI PIATTI 21', 'STRADA SANDA 63', 'BORGATA TETTI ROLLE 45', 'VIA SESTRIERE 49', 'VIA FILIPPO TURATI 2', 'VIA S. MARTINO 35', 'CORSO ROMA 23', 'VIA PLAUTO 8', 'STRADA PASUBIO 38', 'VIA MARIO PANNUNZIO 5', 'VIA DEI MILLE 9', 'VIA S. GIOVANNI BOSCO 6', 'STRADA REVIGLIASCO 15', 'CORSO SAVONA 4', 'STRADA C. FERRERO DI CAMBIANO 51', 'VIA VILLAFRANCA 3', 'CORSO TRIESTE 73', 'VIALE ENRICO BERLINGUER 10', 'STRADA GIORGIO DEVALLE 21', 'VIA TIEPOLO 12', 'VIA S. GIOVANNI BOSCO 18', 'VIA SESTRIERE 13', 'VIA PASTRENGO 130', 'VIA JUGLARIS 62', 'STRADA CENASCO 7', 'VIA QUINTINO SELLA 34', 'STRADA VINOVO 12', 'STRADA VIVERO 10', 'VIA PIAVE 8']

# %%
print(accuracy_score(true_indirizzi, pred_indirizzi))

# %%
count=0
for x in range(1000):
  if pred_indirizzi[x] in true_indirizzi[x]:
    count += 1
  else:
     print(pred_indirizzi[x]) 
     print(true_indirizzi[x])
print(count)
# Out:
# VIA S. VINCENZO 7
# VIA S.VINCENZO 7
# VIA S. MATTEO 6
# VIA S.MATTEO 6
# VIA S. GIOVANNI BOSCO 18
# VIA S.GIOVANNI BOSCO 18
# STRADA MARSE'25
# STRADA MARSE' 25 3
# STRADA MARSE'27
# STRADA MARSE' 27 3
# VIA S. VINCENZO 5
# VIA S.VINCENZO 5
# UKR CORSO TRIESTE 59
# CORSO TRIESTE 59
# STRADA MARSE'49
# STRADA MARSE' 49
# BORGATA PIATTI 77
# BORGATA TETTI PIATTI 77 17
# VIA S. MARTINO 18
# VIA S.MARTINO 18
# VIA S. GIOVANNI BOSCO 4
# VIA S.GIOVANNI BOSCO 4
# STRADA MARSE'3
# STRADA MARSE' 3
# STRADA S. BRIGIDA 64
# STRADA S.BRIGIDA 64 1
# STRADA S. MICHELE 9
# STRADA S.MICHELE 9
# VIA S. VINCENZO 3
# VIA S.VINCENZO 3
# VIA S. MARIA 35
# VIA S.MARIA 35 10
# MAR CORSO SAVONA 102
# CORSO SAVONA 102
# VIA MARTIRI DELLA LIBERTA'12
# VIA MARTIRI DELLA LIBERTA' 12
# VIA S. MARTINO 20
# VIA S.MARTINO 20
# VIA S. GIOVANNI BOSCO 6
# VIA S.GIOVANNI BOSCO 6
# VIA GIOSUE'CARDUCCI 20
# VIA GIOSUE' CARDUCCI 20
# VIA GIOSUE'CARDUCCI 6
# VIA GIOSUE' CARDUCCI 6
# VIA GIOSUE'CARDUCCI 13
# VIA GIOSUE' CARDUCCI 13 BIS
# STRADA MARSE'4
# STRADA MARSE' 4
# UKR STRADA ROSARIO SCALERO 20
# STRADA ROSARIO SCALERO 20
# VIA S. CROCE 46
# VIA S.CROCE 46
# VIA S. MARTINO 13
# VIA S.MARTINO 13
# BORGATA PIATTI 77
# BORGATA TETTI PIATTI 77 7
# STRADA S. MICHELE 1
# STRADA S.MICHELE 1
# VIA GIOSUE'CARDUCCI 12
# VIA GIOSUE' CARDUCCI 12 3
# BORGATA PIATTI 79
# BORGATA TETTI PIATTI 79
# BORGATA PIATTI 24
# BORGATA TETTI PIATTI 24
# STRADA S. BRIGIDA 93
# STRADA S.BRIGIDA 93 19
# STRADA S. BRIGIDA 9
# STRADA S.BRIGIDA 9
# VIA S. CROCE 40
# VIA S.CROCE 40
# VIA MARTIRI DELLA LIBERTA'10
# VIA MARTIRI DELLA LIBERTA' 10
# VIA S. VINCENZO 3
# VIA S.VINCENZO 3
# VIA S. CROCE 12
# VIA S.CROCE 12
# ROU CORSO DANTE 11
# CORSO DANTE 11
#  VIA S. MARIA 82
# VIA S.MARIA 82
# VIA S. GIOVANNI BOSCO 16
# VIA S.GIOVANNI BOSCO 16
# DOM VIA VITTIME DI PIAZZA FONTANA 56
# VIA VITTIME DI PIAZZA FONTANA 56
# STRADA S. BRIGIDA 59
# STRADA S.BRIGIDA 59
# VIA S. MARIA 25
# VIA S.MARIA 25
# ROU CORSO ROMA 62
# CORSO ROMA 62
# VIA S. GIOVANNI BOSCO 14
# VIA S.GIOVANNI BOSCO 14
# STRADA MARSE'31
# STRADA MARSE' 31 11
# ROU STRADA CARIGNANO 34
# STRADA CARIGNANO 34 BIS
# VIA S. GIOVANNI BOSCO 14
# VIA S.GIOVANNI BOSCO 14
# VIA S. MARIA 47
# VIA S.MARIA 47
# STRADA S. MICHELE 35
# STRADA S.MICHELE 35
# VIA S. CROCE 10
# VIA S.CROCE 10
# VIA S. GIOVANNI BOSCO 6
# VIA S.GIOVANNI BOSCO 6
# VIA GIOSUE'CARDUCCI 7
# VIA GIOSUE' CARDUCCI 7
# STRADA MARSE'31
# STRADA MARSE' 31 1
# STRADA S. BRIGIDA 94
# STRADA S.BRIGIDA 94
# STRADA MARSE'153
# STRADA MARSE' 153
# VIA S. MARTINO 12
# VIA S.MARTINO 12
# VIA S. GIOVANNI BOSCO 18
# VIA S.GIOVANNI BOSCO 18
# STRADA S. BRIGIDA 32
# STRADA S.BRIGIDA 32
# STRADA VADO'3
# STRADA VADO' 3
# STRADA S. MICHELE 18
# STRADA S.MICHELE 18
# VIA NICOLO'TOMMASEO 5
# VIA NICOLO' TOMMASEO 5
# VIA MARTIRI DELLA LIBERTA'6
# VIA MARTIRI DELLA LIBERTA' 6
# VIA S. CROCE 19
# VIA S.CROCE 19
# ROU STRADA GENOVA 241
# STRADA GENOVA 241 4
# VIA S. MARIA 23
# VIA S.MARIA 23
# VIA S. VINCENZO 7
# VIA S.VINCENZO 7
# STRADA MARSE'31
# STRADA MARSE' 31 13
# STRADA BOCCIA D ORO 14
# STRADA BOCCIA D'ORO 14
# STRADA MARSE'53
# STRADA MARSE' 53
# VIA S. CROCE 29
# VIA S.CROCE 29
# MAR CORSO TRIESTE 73
# CORSO TRIESTE 73
# STRADA S. BRIGIDA 44
# STRADA S.BRIGIDA 44
# STRADA MARSE'31
# STRADA MARSE' 31
# VIA S. MARIA 45
# VIA S.MARIA 45
# STRADA MARSE'25
# STRADA MARSE' 25 4
# 923

# %%
def confidence(acc, N, Z):
    den = (2*(N+Z**2))
    var = (Z*np.sqrt(Z**2+4*N*acc-4*N*acc**2)) / den
    a = (2*N*acc+Z**2) / den
    inf = a - var
    sup = a + var
    return inf, sup

# %%
inf_ind, sup_ind = confidence(accuracy_score(true_indirizzi, pred_indirizzi), 1000, 1.96)

# %%
inf_co, sup_co = confidence(accuracy_score(true_cognomi, pred_cognomi), 1000, 1.96)

# %%
inf_nomi, sup_nomi = confidence(accuracy_score(true_nomi, pred_nomi), 1000, 1.96)

# %%
from prettytable import PrettyTable
x = PrettyTable()
x.field_names = ["Campo","Accuracy", "Inf", "Sup"]


x.add_row(['Indirizzo',accuracy_score(true_indirizzi, pred_indirizzi),inf_ind,sup_ind])
x.add_row(['Nome', accuracy_score(true_nomi, pred_nomi), inf_nomi,sup_nomi])
x.add_row(['Cognome', accuracy_score(true_cognomi, pred_cognomi),inf_co,sup_co ])




print(x)
# Out:
# +-----------+----------+--------------------+--------------------+
# |   Campo   | Accuracy |        Inf         |        Sup         |
# +-----------+----------+--------------------+--------------------+
# | Indirizzo |  0.661   | 0.6310938159758936 | 0.6896739226792885 |
# |    Nome   |  0.909   | 0.8895740291786208 | 0.9252955677777118 |
# |  Cognome  |  0.912   | 0.8928273665502449 | 0.9280192690145694 |
# +-----------+----------+--------------------+--------------------+
